# %%
help(complex)

# %%
complex_number = complex(2,3)
print(complex_number.imag) # мнимая часть
print(complex_number.real) # действительная часть
# complex_number.conjugate() # сопряженное число / число с противоположным знаком
# complex_number
# Out:
# 3.0
# 2.0

# %%
type(complex_number) # complex number
# Out:
# complex

# %%
complex_number.conjugate() + complex_number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\anisi\OneDrive\Документы\GitHub\Python-Anisiya\Math\lesson_math_complex.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/anisi/OneDrive/%D0%94%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/GitHub/Python-Anisiya/Math/lesson_math_complex.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> complex_number.conjugate() + complex_number
#
# NameError: name 'complex_number' is not defined

# %%
# complex(25**(1/2))
complex(5j**(2)).real
# Out:
# -25.0

# %%
import numpy as np

np.log(10)
# Out:
# 2.302585092994046

# %%
np.array([1+2j]) #.array - создание масива
# Out:
# array([1.+2.j])

# %%
np.gcd(10,100) # наибольший общий делитель
# Out:
# 10

# %%
np.lcm(10,100) # наименьшее общее кратное
# Out:
# 100
